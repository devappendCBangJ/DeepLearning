# %%
import argparse
import easydict

import torch.nn as nn
import torch.optim as optim
import torchvision.transforms as T

from torchvision.datasets import ImageFolder
from torch.utils.data import DataLoader
from torchmetrics.functional.classification import accuracy

from src.engines import pretrain_baseline
from src.models import BaselineNet
from src.utils import save_checkpoint, save_pretrained_embeddingnet

# Colab 환경
# parser = argparse.ArgumentParser()
# parser.add_argument("--title", type=str, default="transfer")
# parser.add_argument("--device", type=str, default="cuda")
# parser.add_argument("--root", type=str, default="data/omniglot/meta-train")
# parser.add_argument("--num_workers", type=int, default=2)
# parser.add_argument("--num_classes", type=int, default=1432)
# parser.add_argument("--batch_size", type=int, default=16)
# parser.add_argument("--epochs", type=int, default=100)
# parser.add_argument("--lr", type=float, default=0.001)
# parser.add_argument("--checkpoints", type=str, default='checkpoints')
# parser.add_argument("--pretrain", type=bool, default=True)
# args = parser.parse_args()

# Jupyter 환경
args = easydict.EasyDict({
    "title" : "transfer",
    "device" : "cuda",
    "root" : "data/omniglot/meta-train",
    "num_workers" : 2,
    "num_classes" : 1432,
    "batch_size" : 16,
    "epochs" : 100,
    "lr" : 0.001,
    "checkpoints" : 'checkpoints',
    "pretrain" : True
})


def main(args):
    # Build dataset : train만 진행
    train_transform = T.Compose([
        T.Grayscale(),
        T.RandomCrop((32, 32), padding=4),
        T.ToTensor(),
    ])
    train_data = ImageFolder(args.root, transform=train_transform)
    train_loader = DataLoader(train_data, args.batch_size, shuffle=True, num_workers=args.num_workers, drop_last=True) # DataLoader : 새로운 차원에 batch 생성

    # Build model
    model = BaselineNet(args.num_classes, pretrain=args.pretrain)

    model = model.to(args.device)

    # Build optimizer 
    optimizer = optim.Adam(model.parameters(), lr=args.lr)
    scheduler = optim.lr_scheduler.CosineAnnealingLR(optimizer, args.epochs * len(train_loader))
    loss_fn = nn.CrossEntropyLoss()
    metric_fn = accuracy

    # Main loop : train만 진행
    for epoch in range(args.epochs):
        train_summary = pretrain_baseline(train_loader, model, optimizer, scheduler, loss_fn, metric_fn, args.device)
        
        print(f'Epoch: {epoch + 1}, Train Accuracy: {train_summary["metric"]:.4f}')
        save_checkpoint(args.checkpoints, args.title, model, optimizer, epoch + 1)
    
    save_pretrained_embeddingnet(args.checkpoints, args.title, model.features) # model이 아닌, model.features를 인수로 사용 ♣


if __name__=="__main__":
    main(args)
# Out:
# Epoch: 1, Train Accuracy: 0.0011
# Epoch: 2, Train Accuracy: 0.0289
# Epoch: 3, Train Accuracy: 0.2341
# Epoch: 4, Train Accuracy: 0.4600
# Epoch: 5, Train Accuracy: 0.5839
# Epoch: 6, Train Accuracy: 0.6543
# Epoch: 7, Train Accuracy: 0.6880
# Epoch: 8, Train Accuracy: 0.7206
# Epoch: 9, Train Accuracy: 0.7416
# Epoch: 10, Train Accuracy: 0.7637
# Epoch: 11, Train Accuracy: 0.7755
# Epoch: 12, Train Accuracy: 0.7918
# Epoch: 13, Train Accuracy: 0.8008
# Epoch: 14, Train Accuracy: 0.8100
# Epoch: 15, Train Accuracy: 0.8216
# Epoch: 16, Train Accuracy: 0.8311
# Epoch: 17, Train Accuracy: 0.8376
# Epoch: 18, Train Accuracy: 0.8429
# Epoch: 19, Train Accuracy: 0.8500
# Epoch: 20, Train Accuracy: 0.8537
# Epoch: 21, Train Accuracy: 0.8607
# Epoch: 22, Train Accuracy: 0.8683
# Epoch: 23, Train Accuracy: 0.8707
# Epoch: 24, Train Accuracy: 0.8743
# Epoch: 25, Train Accuracy: 0.8776
# Epoch: 26, Train Accuracy: 0.8837
# Epoch: 27, Train Accuracy: 0.8862
# Epoch: 28, Train Accuracy: 0.8914
# Epoch: 29, Train Accuracy: 0.8897
# Epoch: 30, Train Accuracy: 0.8973
# Epoch: 31, Train Accuracy: 0.8991
# Epoch: 32, Train Accuracy: 0.9013
# Epoch: 33, Train Accuracy: 0.9052
# Epoch: 34, Train Accuracy: 0.9060
# Epoch: 35, Train Accuracy: 0.9097
# Epoch: 36, Train Accuracy: 0.9136
# Epoch: 37, Train Accuracy: 0.9148
# Epoch: 38, Train Accuracy: 0.9167
# Epoch: 39, Train Accuracy: 0.9174
# Epoch: 40, Train Accuracy: 0.9194
# Epoch: 41, Train Accuracy: 0.9235
# Epoch: 42, Train Accuracy: 0.9245
# Epoch: 43, Train Accuracy: 0.9269
# Epoch: 44, Train Accuracy: 0.9289
# Epoch: 45, Train Accuracy: 0.9297
# Epoch: 46, Train Accuracy: 0.9326
# Epoch: 47, Train Accuracy: 0.9350
# Epoch: 48, Train Accuracy: 0.9338
# Epoch: 49, Train Accuracy: 0.9375
# Epoch: 50, Train Accuracy: 0.9394
# Epoch: 51, Train Accuracy: 0.9401
# Epoch: 52, Train Accuracy: 0.9435
# Epoch: 53, Train Accuracy: 0.9428
# Epoch: 54, Train Accuracy: 0.9456
# Epoch: 55, Train Accuracy: 0.9473
# Epoch: 56, Train Accuracy: 0.9480
# Epoch: 57, Train Accuracy: 0.9489
# Epoch: 58, Train Accuracy: 0.9514
# Epoch: 59, Train Accuracy: 0.9519
# Epoch: 60, Train Accuracy: 0.9511
# Epoch: 61, Train Accuracy: 0.9531
# Epoch: 62, Train Accuracy: 0.9532
# Epoch: 63, Train Accuracy: 0.9546
# Epoch: 64, Train Accuracy: 0.9574
# Epoch: 65, Train Accuracy: 0.9578
# Epoch: 66, Train Accuracy: 0.9592
# Epoch: 67, Train Accuracy: 0.9603
# Epoch: 68, Train Accuracy: 0.9613
# Epoch: 69, Train Accuracy: 0.9611
# Epoch: 70, Train Accuracy: 0.9604
# Epoch: 71, Train Accuracy: 0.9622
# Epoch: 72, Train Accuracy: 0.9648
# Epoch: 73, Train Accuracy: 0.9632
# Epoch: 74, Train Accuracy: 0.9669
# Epoch: 75, Train Accuracy: 0.9665
# Epoch: 76, Train Accuracy: 0.9657
# Epoch: 77, Train Accuracy: 0.9672
# Epoch: 78, Train Accuracy: 0.9685
# Epoch: 79, Train Accuracy: 0.9683
# Epoch: 80, Train Accuracy: 0.9691
# Epoch: 81, Train Accuracy: 0.9704
# Epoch: 82, Train Accuracy: 0.9713
# Epoch: 83, Train Accuracy: 0.9711
# Epoch: 84, Train Accuracy: 0.9707
# Epoch: 85, Train Accuracy: 0.9712
# Epoch: 86, Train Accuracy: 0.9736
# Epoch: 87, Train Accuracy: 0.9732
# Epoch: 88, Train Accuracy: 0.9726
# Epoch: 89, Train Accuracy: 0.9727
# Epoch: 90, Train Accuracy: 0.9730
# Epoch: 91, Train Accuracy: 0.9741
# Epoch: 92, Train Accuracy: 0.9739
# Epoch: 93, Train Accuracy: 0.9741
# Epoch: 94, Train Accuracy: 0.9752
# Epoch: 95, Train Accuracy: 0.9741
# Epoch: 96, Train Accuracy: 0.9752
# Epoch: 97, Train Accuracy: 0.9742
# Epoch: 98, Train Accuracy: 0.9748
# Epoch: 99, Train Accuracy: 0.9751
# Epoch: 100, Train Accuracy: 0.9751
