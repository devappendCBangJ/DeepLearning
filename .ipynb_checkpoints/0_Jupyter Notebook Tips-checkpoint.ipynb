# %% [markdown]
# ● 주피터 노트북에 사진 넣기
#     1. 모듈 불러오기 : from IPython.display import Image
#     2. code 안에사진 : Image("파일 경로/파일명.파일 확장자") ♣ 반드시 code 안에서 실행
#     2. markdown 안에 사진 : ![title](파일 경로/파일명.파일 확장자) ♣ 반드시 markdown 안에서 실행
